# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns

from pandas_profiling import ProfileReport

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# Read in csv file
df = pd.read_csv(r'C:\Users\johnc\Desktop\movies.csv')

# %%
# View data
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Generate Profile Report
profile = ProfileReport(df)

# Output
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-02-28 00:33:39.998909&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Identify data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Sort data by gross
df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
# Sort data by budget
df.sort_values(by = ['budget'], inplace = False, ascending = False)
# Out:
#                                           name     rating   genre  year  \
# 7445                         Avengers: Endgame      PG-13  Action  2019
# 7244                    Avengers: Infinity War      PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi      PG-13  Action  2017
# 7066                            Justice League      PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End      PG-13  Action  2007
# ...                                        ...        ...     ...   ...
# 7657                                      Leap        NaN   Drama  2020
# 7659                                 I Am Fear  Not Rated  Horror  2020
# 7660                          Aloha Surf Hotel        NaN  Comedy  2020
# 7664                               Dream Round        NaN  Comedy  2020
# 7667                                 Tee em el        NaN  Horror  2020
#
#                                 released  score     votes            director  \
# ...

# %%
# Sort data by votes
df.sort_values(by = ['votes'], inplace = False, ascending = False)
# Out:
#                           name rating   genre  year  \
# 5243           The Dark Knight  PG-13  Action  2008
# 2443  The Shawshank Redemption      R   Drama  1994
# 5643                 Inception  PG-13  Action  2010
# 2445              Forrest Gump  PG-13   Drama  1994
# 2444              Pulp Fiction      R   Crime  1994
# ...                        ...    ...     ...   ...
# 7660          Aloha Surf Hotel    NaN  Comedy  2020
# 7667                 Tee em el    NaN  Horror  2020
# 7661          Love by Drowning      R   Drama  2020
# 7662             The Robinsons    NaN  Action  2020
# 7666              It's Just Us    NaN   Drama  2020
#
#                                released  score      votes            director  \
# 5243      July 18, 2008 (United States)    9.0  2400000.0   Christopher Nolan
# 2443   October 14, 1994 (United States)    9.3  2400000.0      Frank Darabont
# 5643      July 16, 2010 (United States)    8.8  2100000.0   Christopher Nolan
# ...

# %%
# Check which, if any, data points are strongly correlated

# Pearson = parametric correlation
df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# Represent Pearson Correlation with matrix

# Matrix indicates strongest correlation between budget and gross
correlation_matrix = df.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Pearson Correlation")

plt.show()

# %%
# Plot budget vs. gross using strip plot
sns.stripplot(x = "budget", y = "gross", data = df)
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Check which, if any, data points are strongly correlated

# Kendall = non-parametric correlation
df.corr(method = 'kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
# Represent Kendall Correlation with matrix

# Matrix indicates strongest correlation between votes and gross

correlation_matrix = df.corr(method = 'kendall')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Kendall Correlation")

plt.show()

# %%
# Plot votes vs. gross using strip plot
sns.stripplot(x = "votes", y = "gross", data = df)
# Out:
# <AxesSubplot:xlabel='votes', ylabel='gross'>

# %%
# Tally gross per director
director_gross_sum = df.groupby(['director'])[["gross"]].sum()

# Sort 15 highest grossing directors
director_gross_sum_sorted = director_gross_sum.sort_values(['gross','director'], ascending = False)[:15]

# Cast total as 64 bit integer
director_gross_sum_sorted = director_gross_sum_sorted['gross'].astype('int64') 

# Output
director_gross_sum_sorted
# Out:
# director
# Steven Spielberg     9629049370
# Anthony Russo        6844248984
# Peter Jackson        6618045788
# Michael Bay          6451692798
# James Cameron        6248088578
# David Yates          6021591899
# Christopher Nolan    5153547948
# J.J. Abrams          4659375464
# Tim Burton           4456348890
# Ron Howard           4409188200
# Jon Favreau          4364675953
# Robert Zemeckis      4286713824
# Chris Columbus       4133016380
# Ridley Scott         4006715694
# Roland Emmerich      3868662044
# Name: gross, dtype: int64

# %%
# Tally gross per company
company_gross_sum = df.groupby(['company'])[["gross"]].sum()

# Sort 15 highest grossing companies
company_gross_sum_sorted = company_gross_sum.sort_values(['gross','company'], ascending = False)[:15]

# Cast total as 64 bit integer
company_gross_sum_sorted = company_gross_sum_sorted['gross'].astype('int64') 

# Output
company_gross_sum_sorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64
